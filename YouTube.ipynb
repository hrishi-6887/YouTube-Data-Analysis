# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("Global YouTube Statistics.csv",encoding ="latin1")

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.tail()
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pd.set_option("display.float_format","{:.2f}".format)

# %%
category_subscribers_mean=df.groupby("category")["subscribers"].mean()
category_subscribers_mean
# Out:
# category
# Autos & Vehicles        17850000.00
# Comedy                  20123188.41
# Education               26542222.22
# Entertainment           21403319.50
# Film & Animation        28584782.61
# Gaming                  20852127.66
# Howto & Style           19390000.00
# Movies                  25650000.00
# Music                   25717821.78
# News & Politics         20630769.23
# Nonprofits & Activism   27750000.00
# People & Blogs          21056060.61
# Pets & Animals          18100000.00
# Science & Technology    18617647.06
# Shows                   41615384.62
# Sports                  27109090.91
# Trailers                39000000.00
# Travel & Events         12500000.00
# Name: subscribers, dtype: float64

# %%
category_subscribers_mean.plot(kind="bar")
plt.title("Mean Subscribe By Category")
plt.xlabel("Category")
plt.ylabel("Mean Subscribers")

#1e7 = 10 million
# Out:
# Text(0, 0.5, 'Mean Subscribers')

# %%
channel_type_counts=df['channel_type'].value_counts()
channel_type_counts
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
channel_type_counts.head(8).plot(kind='pie',autopct="%1.1f%%")
plt.title('Channel Type Distribution')
# Out:
# Text(0.5, 1.0, 'Channel Type Distribution')

# %%
country_subscribers_total=df.groupby("Country")["subscribers"].sum().sort_values(ascending=False)

# %%
country_subscribers_total
# Out:
# Country
# United States           7329500000
# India                   4310600000
# Brazil                  1221800000
# United Kingdom           917400000
# Mexico                   626900000
# Indonesia                534100000
# South Korea              481700000
# Russia                   407200000
# Thailand                 386500000
# Spain                    385100000
# Canada                   363900000
# Argentina                328500000
# Colombia                 264500000
# Philippines              240100000
# Japan                    189100000
# Saudi Arabia             179100000
# Australia                172000000
# Pakistan                 155400000
# United Arab Emirates     148200000
# Ukraine                  125600000
# Germany                  116400000
# Turkey                    91600000
# Chile                     87200000
# France                    83900000
# Jordan                    67000000
# Sweden                    63000000
# ...

# %%
country_subscribers_total.head(5).plot(kind="bar")
plt.title("Total Subscribers by Country")
plt.xlabel("Country")
plt.ylabel("Total Subscribers")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'United States'),
#   Text(1, 0, 'India'),
#   Text(2, 0, 'Brazil'),
#   Text(3, 0, 'United Kingdom'),
#   Text(4, 0, 'Mexico')])

# %%
df.groupby("channel_type")["video_views_rank"].median().sort_values(ascending=False)
# Out:
# channel_type
# Autos           3468229.00
# Tech               2420.00
# Games              1944.00
# People             1868.00
# Howto              1574.50
# Nonprofit          1537.50
# Sports             1186.00
# Comedy             1033.00
# Film                880.00
# Entertainment       796.00
# News                611.50
# Education           538.00
# Music               385.00
# Animals             136.00
# Name: video_views_rank, dtype: float64

# %%
cat_view=df.groupby("category")["video views"].mean().sort_values(ascending=0)
cat_view.head(10)
# Out:
# category
# Shows              34323602069.92
# Trailers           16631358803.50
# Education          15480321619.98
# Music              15452858943.73
# Sports             13453299147.27
# Film & Animation   11835271941.59
# Pets & Animals     11216686474.75
# Entertainment      10488544853.04
# News & Politics    10399689205.65
# People & Blogs      9589327284.45
# Name: video views, dtype: float64

# %%
df.groupby("channel_type")["uploads"].sum().sort_values(ascending = 0)
# Out:
# channel_type
# News             3989151
# Entertainment    3345035
# Music             424950
# Games             399473
# Nonprofit         205824
# Sports            158995
# Education         146355
# People            117424
# Film              114654
# Comedy             81722
# Howto              79417
# Animals            42868
# Tech               33780
# Autos                949
# Name: uploads, dtype: int64

# %%
# Distribution of earnings based on channel type

sns.boxplot(x="channel_type",y="highest_monthly_earnings",data=df,hue="channel_type", palette="bright",legend=False)
plt.title("Distribution of Highest monthly earnings by channel Type")
plt.xticks(rotation = 90)
plt.show()

# %%
category_highest_monthly_earnings_sum=df.groupby("category")["highest_monthly_earnings"].sum()
category_highest_monthly_earnings_sum
# Out:
# category
# Autos & Vehicles          2172700.00
# Comedy                   46113543.00
# Education                31283000.10
# Entertainment           150056865.14
# Film & Animation         33704283.22
# Gaming                   25559111.38
# Howto & Style             7711962.34
# Movies                     909400.00
# Music                   111564523.95
# News & Politics          16708431.00
# Nonprofits & Activism      780800.00
# People & Blogs           72183154.16
# Pets & Animals            3177729.00
# Science & Technology      3434735.00
# Shows                    26489600.00
# Sports                    8876300.00
# Trailers                   723800.00
# Travel & Events            124000.00
# Name: highest_monthly_earnings, dtype: float64

# %%
category_highest_monthly_earnings_sum.head().plot(kind="pie",autopct="%1.1f%%")
plt.title("Percentange of Highest Monthly Earnings By Category")
plt.ylabel("")
plt.show()

# %%
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
               "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

monthly_avg = df.groupby("created_month")["subscribers_for_last_30_days"].mean().reindex(month_order)
monthly_avg.plot(kind='line', marker="p")
plt.title("Average Subscribers for Last 30 Days by Month")
plt.ylabel("Avg Subscribers for Last 30 Days")
plt.xticks(ticks=range(len(monthly_avg)), labels=monthly_avg.index, rotation=45)
plt.show()
